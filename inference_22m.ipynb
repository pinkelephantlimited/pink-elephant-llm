# %% [markdown]
# # 🐘 Pink Elephant 22M — Interactive Inference
#
# Load the model and type your own prompts to test it.

# %%
# !pip install -q transformers torch

# %%
from transformers import pipeline
import getpass

MODEL = "pinkelephantlimited/pink-elephant-22m"
pipe = pipeline("text-generation", model=MODEL, trust_remote_code=True)
print(f"✅ Loaded {MODEL}")

# %%
prompt = input("Enter your prompt: ")
result = pipe(prompt, max_new_tokens=60, do_sample=True, temperature=0.5)[0]["generated_text"]
print("\n" + result)

# %% [markdown]
# Run the cell above again to enter a new prompt.
